# %%
import pandas as pd

# %%
df = pd.read_csv("rag_evaluation_results.csv")
df
# Out:
#                                           user_input  \
# 0  Bộ luật Lao động số 45/2019/QH14 áp dụng cho n...
# 1  Theo quy định chung, độ tuổi lao động tối thiể...
# 2  Hợp đồng lao động phải được giao kết theo nhữn...
# 3  Người sử dụng lao động không được thực hiện nh...
# 4  Thời gian thử việc tối đa đối với công việc yê...
# 5  Người lao động có quyền đơn phương chấm dứt hợ...
# 6  Khi đơn phương chấm dứt hợp đồng lao động trái...
# 7  Việc tính thời gian làm việc và tiền lương để ...
# 8  Bên thuê lại lao động bị cấm sử dụng lao động ...
# 9  Thỏa ước lao động tập thể doanh nghiệp chỉ đượ...
#
#                                   retrieved_contexts  \
# 0  ['[1] Nguồn: luat_lao_dong.txt — và các quan h...
# 1  ['[1] Nguồn: luat_lao_dong.txt — 1. Người lao ...
# 2  ['[1] Nguồn: luat_lao_dong.txt — 2. Người lao ...
# 3  ['[1] Nguồn: luat_lao_dong.txt — Điều 17. Hành...
# 4  ['[1] Nguồn: luat_lao_dong.txt — và bảo đảm đi...
# 5  ['[1] Nguồn: luat_lao_dong.txt — được thực hiệ...
# ...
